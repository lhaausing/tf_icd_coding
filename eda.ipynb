# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv('~./disch_train_split.csv')

# %%
max_len = max([len(sample.split(' ')) for sample in df1['TEXT']])

# %%
max_len
# Out:
# 11984

# %%
avg_len = np.mean([len(sample.split(' ')) for sample in df1['TEXT']])

# %%
avg_len
# Out:
# 1745.1601324309033

# %%
lens = [len(sample.split(' ')) for sample in df1['TEXT']]

# %%
plt.hist(lens, 100)
# Out:
# (array([3.700e+01, 1.280e+02, 3.230e+02, 7.100e+02, 1.228e+03, 1.850e+03,
#         2.318e+03, 2.779e+03, 2.991e+03, 3.136e+03, 3.126e+03, 3.017e+03,
#         2.897e+03, 2.694e+03, 2.551e+03, 2.284e+03, 2.061e+03, 1.865e+03,
#         1.643e+03, 1.419e+03, 1.256e+03, 1.127e+03, 9.560e+02, 8.010e+02,
#         6.900e+02, 6.030e+02, 4.680e+02, 4.100e+02, 3.470e+02, 2.960e+02,
#         2.330e+02, 2.220e+02, 1.720e+02, 1.600e+02, 1.190e+02, 1.130e+02,
#         8.300e+01, 7.300e+01, 7.400e+01, 5.400e+01, 5.400e+01, 4.200e+01,
#         3.800e+01, 3.200e+01, 2.700e+01, 2.100e+01, 2.100e+01, 1.400e+01,
#         1.300e+01, 1.300e+01, 1.900e+01, 1.400e+01, 1.000e+01, 1.500e+01,
#         1.000e+01, 8.000e+00, 5.000e+00, 1.100e+01, 2.000e+00, 5.000e+00,
#         4.000e+00, 5.000e+00, 4.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#         3.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
# ...

# %%
vocab = pd.read_csv('vocab.csv', header = None)
vocab
# Out:
#                      0
# 0                [CLS]
# 1            admission
# 2                 date
# 3            discharge
# 4                   of
# ...                ...
# 51914   tracheomalatia
# 51915  schwannomatosis
# 51916           ghetto
# 51917      pyocystitis
# 51918            turon
#
# [51919 rows x 1 columns]

# %%
ICDs = pd.read_csv('DIAGNOSES_ICD.csv')

# %%
ICDs
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 1         1298         109   172335      2.0       486
# 2         1299         109   172335      3.0     58281
# 3         1300         109   172335      4.0      5855
# 4         1301         109   172335      5.0      4254
# ...        ...         ...      ...      ...       ...
# 651042  639798       97503   188195      2.0     20280
# 651043  639799       97503   188195      3.0     V5869
# 651044  639800       97503   188195      4.0     V1279
# 651045  639801       97503   188195      5.0      5275
# 651046  639802       97503   188195      6.0      5569
#
# [651047 rows x 5 columns]

# %%
top_50ICDs = pd.read_csv('TOP_50_CODES.csv', header = None)

# %%
top_50ICDs
# Out:
#          0
# 0    401.9
# 1    38.93
# 2    428.0
# 3   427.31
# 4   414.01
# 5    96.04
# 6     96.6
# 7    584.9
# 8   250.00
# 9    96.71
# 10   272.4
# 11  518.81
# 12   99.04
# 13   39.61
# 14   599.0
# 15  530.81
# 16   96.72
# 17   272.0
# 18   285.9
# 19   88.56
# 20   244.9
# 21     486
# 22   38.91
# 23   285.1
# 24   36.15
# 25   276.2
# 26     496
# 27   99.15
# 28  995.92
# 29  V58.61
# 30   507.0
# 31   038.9
# 32   88.72
# 33   585.9
# 34  403.90
# 35     311
# 36   305.1
# 37   37.22
# 38     412
# 39   33.24
# 40   39.95
# 41   287.5
# 42  410.71
# 43   276.1
# 44  V45.81
# 45   424.0
# 46   45.13
# 47  V15.82
# 48   511.9
# 49   37.23

# %%
train_full_hadm_ids = pd.read_csv('train_full_hadm_ids.csv', header = None)

# %%
train_full_hadm_ids
# Out:
#             0
# 0      169433
# 1      178124
# 2      139808
# 3      117638
# 4      190945
# ...       ...
# 47718  105131
# 47719  112625
# 47720  128930
# 47721  172599
# 47722  164627
#
# [47723 rows x 1 columns]

# %%
notes_labeled = pd.read_csv('notes_labeled.csv')

# %%
len(notes_labeled['TEXT'])
# Out:
# 52726

# %%
notes_labeled['TEXT'][0]
# Out:
# '[CLS] admission date discharge date date of birth sex m service medicine chief complaint admitted from rehabilitation for hypotension systolic blood pressure to the 70s and decreased urine output [SEP] [CLS] history of present illness the patient is a year old male who had been hospitalized at the hospital1 from through of after undergoing a left femoral at bypass graft and was subsequently discharged to a rehabilitation facility [SEP] [CLS] on he presented again to the hospital1 after being found to have a systolic blood pressure in the 70s and no urine output for hours [SEP] [CLS] a foley catheter placed at the rehabilitation facility yielded cc of murky brown urine [SEP] [CLS] there may also have been purulent discharge at the penile meatus at this time [SEP] [CLS] on presentation to the emergency department the patient was without subjective complaints [SEP] [CLS] in the emergency department he was found to have systolic blood pressure of [SEP] [CLS] he was given liters of intra
# ...
